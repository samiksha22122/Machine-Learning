# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
from mpl_toolkits.mplot3d import Axes3D
from sklearn.datasets import make_blobs

# %%
centers = [[2,2,2],[7,7,7],[5,13,13]]

# %%
X,_ = make_blobs(n_samples=150,centers=centers,cluster_std=0.60)

# %%
X
# Out:
# array([[ 6.23280329, 13.52156486, 12.36626855],
#        [ 4.49527185, 12.20325071, 13.58912649],
#        [ 6.38537783,  7.04982866,  7.17224926],
#        [ 6.50012342,  7.50771147,  6.77126592],
#        [ 2.32846772,  1.47898966,  1.93744625],
#        [ 6.29235303,  6.65601506,  6.48211516],
#        [ 2.10930238,  1.79962734,  2.22928356],
#        [ 6.93401924,  6.72811561,  6.6327394 ],
#        [ 1.52942344,  1.16115482,  0.4501888 ],
#        [ 7.3970351 ,  6.14504386,  7.42925958],
#        [ 2.20068406,  1.69414105,  2.31732479],
#        [ 2.6816639 ,  1.71708317,  1.98465906],
#        [ 5.2038211 , 12.80002981, 13.34753044],
#        [ 7.71836607,  6.96994953,  7.51399964],
#        [ 5.27297029, 12.64816069, 13.4847134 ],
#        [ 1.9880112 ,  2.06293271,  1.86051584],
#        [ 7.54451795,  7.9646779 ,  6.77063963],
#        [ 4.49078411, 12.75659237, 13.03215041],
#        [ 5.34489111, 13.34006946, 13.79250359],
#        [ 1.69495441,  1.9463936 ,  2.25817141],
#        [ 2.28542298,  2.25290911,  2.07196204],
#        [ 7.41929666,  7.3154076 ,  7.51389109],
#        [ 7.42729694,  7.58721961,  7.31299229],
#        [ 4.33314974, 12.56163103, 13.52036125],
#        [ 4.38302907, 12.24216053, 12.05003275],
#        [ 3.82771344, 11.87438861, 14.92076327],
#        [ 3.45792143,  0.85458115,  1.59266634],
#        [ 5.94161428, 11.78170833, 12.787323  ],
#        [ 6.41424909, 12.87212406, 12.43029273],
#        [ 8.0010331 ,  7.50440322,  7.7235281 ],
#        [ 7.5059115 ,  5.80886782,  6.45649528],
#        [ 5.92184663, 12.55150795, 13.3433985 ],
#        [ 7.56084224,  7.34549818,  7.68834618],
#        [ 7.26147213,  7.86029507,  6.96530992],
#        [ 4.96344332,  7.02776722,  8.47446488],
#        [ 4.25925785, 12.51769299, 12.1472655 ],
#        [ 2.07519209,  1.13131069,  2.63538287],
#        [ 7.04160686,  6.57951462,  7.03533841],
#        [ 6.92148407,  7.5135489 ,  6.78017867],
#        [ 4.85985008, 13.65637894, 13.83738822],
#        [ 5.38727119, 12.44115828, 13.51342865],
#        [ 7.57311064,  6.83318409,  6.63901085],
#        [ 6.51775782,  7.33549451,  6.75941717],
#        [ 1.73645964,  2.01235395,  2.98542686],
#        [ 6.91665035,  6.0194554 ,  6.61452452],
#        [ 2.62029379,  1.93039863,  2.99590959],
#        [ 7.68279641,  6.8058121 ,  7.40901133],
#        [ 2.79964317,  1.69943017,  1.12038007],
#        [ 2.69244365,  0.85796276,  2.50460772],
#        [ 2.05097449,  1.3855826 ,  2.21087449],
#        [ 5.42090768, 12.72080613, 13.26234351],
#        [ 6.0570409 ,  6.69973427,  6.18101513],
#        [ 7.81357819,  7.08397879,  6.93236488],
#        [ 6.06013359, 13.29286692, 12.68573881],
#        [ 2.27728176,  2.34361299,  2.2229874 ],
#        [ 4.98354344, 13.82797928, 12.51363441],
#        [ 4.48152593, 13.81034186, 13.04856461],
#        [ 4.28383856, 13.26567839, 11.74723554],
#        [ 4.80449398, 12.2867652 , 12.46376082],
#        [ 2.05344823,  1.69582699,  1.75981971],
#        [ 5.24183175, 12.77746992, 13.95288731],
#        [ 4.78519354, 13.72014564, 12.37727337],
#        [ 2.04045766,  2.27533564,  2.03859877],
#        [ 4.03147501, 13.00301104, 11.93862382],
#        [ 6.21759083,  5.712726  ,  8.13962062],
#        [ 5.09700727, 11.70109559, 12.89335433],
#        [ 5.89276142, 14.02602221, 12.62480815],
#        [ 1.41611761,  2.55956206,  2.51302774],
#        [ 3.63947228, 13.03869948, 12.46835202],
#        [ 7.46683111,  6.47698917,  7.34920036],
#        [ 1.93420852,  3.03027003,  1.31892582],
#        [ 2.66699772,  1.73070571,  2.35426771],
#        [ 2.31527764,  1.93884105,  2.5305764 ],
#        [ 6.50791212,  7.66351508,  7.38889749],
#        [ 1.41335591,  2.21025134,  2.30431067],
#        [ 4.71811798, 12.67019022, 14.29400686],
#        [ 7.59921196,  5.99703019,  6.96611726],
#        [ 2.63185474,  1.66166339,  3.13632637],
#        [ 5.32043387, 13.41721251, 12.93953332],
#        [ 4.71624451, 12.97010529, 13.00634831],
#        [ 6.40492704,  7.00912968,  8.36571002],
#        [ 5.87668804, 12.10792527, 13.39255327],
#        [ 6.80444267,  7.56930147,  7.67927988],
#        [ 7.43887169,  7.70370071,  7.25171259],
#        [ 4.44755988, 13.76201033, 13.63904754],
#        [ 5.55842053, 13.75691456, 13.79945224],
#        [ 2.15056684,  2.22389258,  2.33698488],
#        [ 5.45886346,  7.12300685,  6.56042796]])

# %%
fig = plt.figure(figsize=(8,10))
ax = fig.add_subplot(111,projection='3d')
ax.scatter(X[:,0],X[:,1],X[:,2])
plt.show()

# %%
from sklearn.cluster import MeanShift

# %%
ms = MeanShift()

# %%
ms.fit(X)
# Out:
# MeanShift()

# %%
identified_clusters = ms.fit_predict(X)

# %%
identified_clusters
# Out:
# array([2, 2, 1, 1, 0, 1, 0, 1, 0, 1, 0, 0, 2, 1, 2, 0, 1, 2, 2, 0, 0, 1,
#        1, 2, 2, 2, 0, 2, 2, 1, 1, 2, 1, 1, 1, 2, 0, 1, 1, 2, 2, 1, 1, 0,
#        1, 0, 1, 0, 0, 0, 2, 1, 1, 2, 0, 2, 2, 0, 0, 1, 2, 0, 2, 0, 2, 0,
#        0, 1, 2, 2, 1, 0, 1, 1, 0, 0, 2, 2, 1, 1, 0, 0, 2, 1, 2, 0, 0, 2,
#        0, 1, 1, 0, 1, 0, 0, 1, 2, 2, 1, 2, 0, 1, 0, 1, 0, 0, 2, 0, 1, 0,
#        1, 2, 0, 0, 1, 1, 2, 2, 1, 2, 2, 0, 2, 2, 0, 2, 1, 2, 2, 0, 2, 1,
#        0, 0, 0, 1, 0, 2, 1, 0, 2, 2, 1, 2, 1, 1, 2, 2, 0, 1], dtype=int64)

# %%
fig = plt.figure(figsize=(8,10))
ax = fig.add_subplot(111,projection='3d')
ax.scatter(X[:,0],X[:,1],X[:,2],c=identified_clusters,cmap='rainbow')
plt.show()

# %%
# Kmeans

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(2)

# %%
kmeans.fit(X)
# Out:
# KMeans(n_clusters=2)

# %%
identified_clusters = kmeans.fit_predict(X)

# %%
fig = plt.figure(figsize=(8,10))
ax = fig.add_subplot(111,projection='3d')
ax.scatter(X[:,0],X[:,1],X[:,2],c=identified_clusters,cmap='rainbow')
plt.show()
